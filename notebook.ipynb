# %%
DATA = './dataset/matches.csv'

# %%
import pandas as pd

# %%
data=pd.read_csv(DATA)

# %%
data.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
data.info
# Out:
# <bound method DataFrame.info of         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %% [markdown]
# # Q1

# %%
# Q1
print('Total Matches: ', data.shape[0])
print('\nColumns')
for col in data.columns:
    print(col)
print('\n5 rows of data')
print(data.head(5))
print('\ndescribe data')
data.describe()
# Out:
# Total Matches:  756
#
# Columns
# id
# Season
# city
# date
# team1
# team2
# toss_winner
# toss_decision
# result
# dl_applied
# winner
# win_by_runs
# win_by_wickets
# player_of_match
# venue
# umpire1
# umpire2
# umpire3
#
# 5 rows of data
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# ...

# %% [markdown]
# # Q2

# %%
da1=data['player_of_match'].where(data['win_by_runs']==int(1))
da2=data['player_of_match'].where(data['win_by_wickets']==int(1))

# %%
da1
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#          ...
# 751          NaN
# 752          NaN
# 753          NaN
# 754          NaN
# 755    JJ Bumrah
# Name: player_of_match, Length: 756, dtype: object

# %%
da1.isna().value_counts()
# Out:
# player_of_match
# True     746
# False     10
# Name: count, dtype: int64

# %%
da2
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 751    NaN
# 752    NaN
# 753    NaN
# 754    NaN
# 755    NaN
# Name: player_of_match, Length: 756, dtype: object

# %%
da2.isna().value_counts()
# Out:
# player_of_match
# True     753
# False      3
# Name: count, dtype: int64

# %%
new_data=pd.merge(da1, da2, on=['player_of_match'], how='outer')

# %%
new_data['player_of_match'].where(new_data['player_of_match'].notnull())
# Out:
# 0            A Nehra
# 1         AD Russell
# 2          CH Morris
# 3           DJ Bravo
# 4          JJ Bumrah
#              ...
# 561746           NaN
# 561747           NaN
# 561748           NaN
# 561749           NaN
# 561750           NaN
# Name: player_of_match, Length: 561751, dtype: object

# %% [markdown]
# # Q3

# %%
data.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
std=data[data['venue'].str.contains("Wankhede Stadium", case=False, na=False)]
wbr=std[std['win_by_runs']>0].shape[0]
wbw=std[std['win_by_wickets']>0].shape[0]
if wbr>wbw:
    print('Win by batting first')
else:
    print('batting second')
# Out:
# batting second

# %% [markdown]
# # Q4

# %%
data.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 751                 Mumbai Indians
# 752                 Mumbai Indians
# 753                 Delhi Capitals
# 754            Chennai Super Kings
# 755                 Mumbai Indians
# Name: winner, Length: 756, dtype: object

# %%
data['winner'].where(data['win_by_runs']>int(50)).value_counts()
# Out:
# winner
# Chennai Super Kings            13
# Mumbai Indians                 10
# Royal Challengers Bangalore     7
# Rajasthan Royals                6
# Kings XI Punjab                 4
# Delhi Daredevils                4
# Kolkata Knight Riders           3
# Deccan Chargers                 3
# Sunrisers Hyderabad             2
# Rising Pune Supergiant          1
# Name: count, dtype: int64

# %% [markdown]
# # Q5

# %%
data.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
new_data=(data['toss_winner']==data['winner'])&(data['win_by_runs']>0)

# %%
res=new_data.sum()
print(res)
# Out:
# 135

# %% [markdown]
# # Q6

# %%
data.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.dtypes
# Out:
# id                  int64
# Season             object
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# umpire3            object
# dtype: object

# %%
d1=data[['umpire1', 'umpire2']].where(data['team1']=='Kolkata Knight Riders')
d2=data[['umpire1', 'umpire2']].where(data['team2']=='Kolkata Knight Riders')
# d1.notnull().value_counts()+d2.notnull().value_counts()
d1.where(d1.notnull()).value_counts()+d2.where(d2.notnull()).value_counts()
# Out:
# umpire1          umpire2
# A Deshmukh       NJ Llong          NaN
# A Nand Kishore   BNJ Oxenford      NaN
#                  S Ravi            NaN
# A Nanda Kishore  Anil Chaudhary    NaN
# AK Chaudhary     CK Nandan         3.0
#                                   ...
# SK Tarapore      SJA Taufel        NaN
# SL Shastri       RB Tiffin         NaN
# SS Hazare        RB Tiffin         NaN
#                  SJA Taufel        3.0
# Yeshwant Barde   O Nandan          NaN
# Name: count, Length: 130, dtype: float64
